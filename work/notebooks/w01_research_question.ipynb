# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# Lane: Refresh / Content Opportunity Scoring
# I chose this lane because the starter notebooks already showed strong evidence
# that a learned model can beat a simple hand-written rule on this exact problem -
# Precision@50 went from 0.24 (baseline) to 0.74 (random forest), meaning the
# model correctly identified about 3x more true refresh candidates in its top 50.
# This shows there is real, learnable signal in this data.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision: Which pages should a limited-capacity review team look at FIRST
# for content refresh, expansion, or protection?
#
# Who acts on it: A content reviewer or SEO team member with limited time -
# they can only manually review a small number of pages per week.
#
# Action taken: Based on the ranked recommendation, the reviewer decides to
# refresh outdated content, expand thin pages, protect high performers, or
# simply monitor a page.
#
# Cost of a wrong call: If a low-priority page is ranked high, the reviewer
# wastes limited time on it while a genuinely declining page is missed and
# continues losing visibility. The cost is wasted reviewer time and a missed
# opportunity - not catastrophic, but a real inefficiency.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, subprocess

REPO_URL = "https://github.com/hibathakur559-boop/flyrank-ml-Hiba"
REPO_DIR = "flyrank-ml-Hiba"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)
print("Working dir:", os.getcwd())
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

declining_count = (df['trend_direction'] == 'down').sum()
print(f"Pages currently declining: {declining_count} out of {len(df)}")

declining_with_demand = df[(df['trend_direction'] == 'down') & (df['impressions_90d'] >= 100)]
print(f"Declining pages with 100+ impressions (worth reviewing): {len(declining_with_demand)}")

print("Starter pipeline result: baseline rule Precision@50 = 0.24, random forest Precision@50 = 0.74")
# Out:
# Working dir: /content/flyrank-ml-Hiba/flyrank-ml-Hiba/flyrank-ml-Hiba/flyrank-ml-Hiba
# Pages currently declining: 16262 out of 30000
# Declining pages with 100+ impressions (worth reviewing): 13152
# Starter pipeline result: baseline rule Precision@50 = 0.24, random forest Precision@50 = 0.74

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# What I CAN claim: Based on observed historical data, certain pages show
# patterns (declining trend, low CTR relative to position, thin content)
# that are directionally associated with being good candidates for review.
# This is decision-support - it helps prioritize where a human should look.
#
# What I CANNOT claim: I cannot claim that refreshing a page will CAUSE
# a recovery in traffic - that would require a controlled experiment.
# I also cannot claim to have discovered or predicted anything about
# Google's actual ranking algorithm - I only observe correlations in
# FlyRank's own anonymized performance data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
